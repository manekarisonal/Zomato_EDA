# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/zomato-eda/zomato.csv

# %%
import pandas as pd
df=pd.read_csv("/kaggle/input/zomato-eda/zomato.csv")
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
import pandas as pd
import numpy as np

# %%
df.drop(['url', "address"], axis=1,inplace=True)
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                             phone  \
# ...

# %%
df.rename(columns = {'phone':'mobile'},inplace = True)
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                            mobile  \
# ...

# %%
df.drop_duplicates()
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                            mobile  \
# ...

# %%
df['rate']=df['rate'].str.replace("/5",'')
df['rate']=df['rate'].str.replace('NEW','0')
df['rate']=df['rate'].str.replace('nan','0')
df['rate']=df['rate'].str.replace('-','0')
df['rate']=df['rate'].astype('float64')
df['rate']
# df
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51712    3.6
# 51713    NaN
# 51714    NaN
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51717, dtype: float64

# %%
# Out:
# <bound method Series.unique of 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 51712   NaN
# 51713   NaN
# 51714   NaN
# 51715   NaN
# 51716   NaN
# Name: rate, Length: 51717, dtype: float64>

# %%
df['rate']=df['rate'].str.replace('NEW','0')

# %%
df['rate'].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 0. , 2.9, 3.5, nan, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4,
#        2.2, 2.3, 4.8, 4.9, 2.1, 2. , 1.8])

# %%
df['rate']=df['rate'].str.replace('nan','0')

# %%
df['rate']=df['rate'].str.replace('-','0')

# %%
df['rate']=df['rate'].astype('float64')

# %%
df.dropna()
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
# Out:
# RangeIndex(start=0, stop=51717, step=1)

# %%
import seaborn as sns
sns.countplot(x ='online_order',data = df)
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %% [markdown]
# Here we are checking Restaurants delivering Online or not by using countplot

# %% [markdown]
# online_order.value_counts()

# %%
sns.countplot(x = 'book_table',data = df)
# Out:
# <Axes: xlabel='book_table', ylabel='count'>

# %% [markdown]
# Here we are checking Restaurants allowing table booking or not by using countplot

# %%
sns.scatterplot(x = 'rate',y = 'approx_cost(for two people)',data = df)
# Out:
# <Axes: xlabel='rate', ylabel='approx_cost(for two people)'>

# %% [markdown]
# Here we are scattering the table booking rate vs rate

# %%
df.groupby('location').agg({'rate':'mean'})
# Out:
#                        rate
# location
# BTM                2.740984
# Banashankari       2.997241
# Banaswadi          2.527259
# Bannerghatta Road  2.657485
# Basavanagudi       3.193421
# ...                     ...
# West Bangalore     1.683333
# Whitefield         2.672295
# Wilson Garden      2.688211
# Yelahanka          3.033333
# Yeshwantpur        3.296639
#
# [93 rows x 1 columns]

# %%
sns.barplot(data=df,x ='location',y ='rate')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /opt/conda/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# <Axes: xlabel='location', ylabel='rate'>

# %% [markdown]
# Finding the best location according to the rate

# %%
# Out:
#   Cell In[2], line 1
#     Finding the best location according to the rate
#             ^
# SyntaxError: invalid syntax

# %%
df.rate.fillna(0,inplace = True)
# Out:
# /tmp/ipykernel_33/2985810881.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.rate.fillna(0,inplace = True)

# %%
df['rate'].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 0. , 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2,
#        2.3, 4.8, 4.9, 2.1, 2. , 1.8])

# %%
df['rate'].max()
# Out:
# 4.9

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
sns.barplot(x = 'location', y= 'rate',data = df,palette = 'coolwarm')
plt.xticks(rotation=90)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /opt/conda/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(

# %% [markdown]
# checking the relation between location and rate

# %%
df['rest_type'].unique()
# Out:
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe',
#        'Cafe, Quick Bites', 'Delivery', 'Mess', 'Dessert Parlor',
#        'Bakery, Dessert Parlor', 'Pub', 'Bakery', 'Takeaway, Delivery',
#        'Fine Dining', 'Beverage Shop', 'Sweet Shop', 'Bar',
#        'Beverage Shop, Quick Bites', 'Confectionery',
#        'Quick Bites, Beverage Shop', 'Dessert Parlor, Sweet Shop',
#        'Bakery, Quick Bites', 'Sweet Shop, Quick Bites', 'Kiosk',
#        'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Beverage Shop, Dessert Parlor', 'Takeaway', 'Pub, Casual Dining',
#        'Casual Dining, Bar', 'Dessert Parlor, Beverage Shop',
#        'Quick Bites, Bakery', 'Dessert Parlor, Quick Bites',
#        'Microbrewery, Casual Dining', 'Lounge', 'Bar, Casual Dining',
#        'Food Court', 'Cafe, Bakery', nan, 'Dhaba',
#        'Quick Bites, Sweet Shop', 'Microbrewery',
# ...

# %%
sns.countplot(x = 'rest_type',data = df,palette = 'coolwarm')
# Out:
# <Axes: xlabel='rest_type', ylabel='count'>

# %% [markdown]
# counting the which restaurant type is at highest rate

# %%
sns.violinplot(x = 'rest_type',y = 'rate',data = df,palette = 'rainbow')
# Out:
# <Axes: xlabel='rest_type', ylabel='rate'>

# %% [markdown]
# Distributing the rest_type and rating

# %%
df['listed_in(type)'].unique()
# Out:
# array(['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out',
#        'Drinks & nightlife', 'Pubs and bars'], dtype=object)

# %%
sns.countplot(x = 'listed_in(type)',data = df,palette = 'Set1')
# Out:
# <Axes: xlabel='listed_in(type)', ylabel='count'>

# %% [markdown]
# counting the which types of Services at highest rate

# %%
sns.barplot(x = 'rest_type',y = 'rate',data = df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /opt/conda/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# <Axes: xlabel='rest_type', ylabel='rate'>

# %% [markdown]
# plotting the relation between Type and Rating

# %%
df['approx_cost(for two people)'] = df['approx_cost(for two people)'].str.replace(',','')
df['approx_cost(for two people)'] = df['approx_cost(for two people)'].str.replace('nan','0')

# %%
df['approx_cost(for two people)'].fillna(0,inplace = True)
# Out:
# /tmp/ipykernel_33/504522494.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['approx_cost(for two people)'].fillna(0,inplace = True)

# %%
df['approx_cost(for two people)'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1200', '350', '250',
#        '950', '1000', '1500', '1300', '199', '80', '1100', '160', '1600',
#        '230', '130', '50', '190', '1700', 0, '1400', '180', '1350',
#        '2200', '2000', '1800', '1900', '330', '2500', '2100', '3000',
#        '2800', '3400', '40', '1250', '3500', '4000', '2400', '2600',
#        '120', '1450', '469', '70', '3200', '60', '560', '240', '360',
#        '6000', '1050', '2300', '4100', '5000', '3700', '1650', '2700',
#        '4500', '140'], dtype=object)

# %%
df['approx_cost(for two people)'] = df['approx_cost(for two people)'].astype('int64')

# %%
a = df.groupby('name').agg({'approx_cost(for two people)':'mean'}).head(20)
a
# Out:
#                                       approx_cost(for two people)
# name
# #FeelTheROLL                                           200.000000
# #L-81 Cafe                                             400.000000
# #Vibes Restro                                          700.000000
# #refuel                                                400.000000
# 'Brahmins' Thatte Idli                                 100.000000
# 1 Fahreheit                                            200.000000
# 1000 B.C                                               300.000000
# 100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C                   450.000000
# 11 to 11 Express Biriyanis                             300.000000
# 1131 Bar + Kitchen                                    1500.000000
# 12th Main - Grand Mercure                             2000.000000
# 1441 Pizzeria                                          800.000000
# 1522 - The Pub                                        1400.000000
# ...

# %%
sns.barplot(x ='approx_cost(for two people)',y =a.index ,data = a)
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='name'>
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:82: UserWarning: Glyph 131 (\x83) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/events.py:82: UserWarning: Glyph 130 (\x82) missing from current font.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 131 (\x83) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 130 (\x82) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Cost of Restaurant according to the people and place

# %%
b = df.groupby('location')['name'].count().sort_values().head(10)
b.plot(kind = 'bar')
# Out:
# <Axes: xlabel='location'>

# %% [markdown]
# finding No. of restaurants in a Location

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
sns.countplot(x = 'rest_type',data = df)
# Out:
# <Axes: xlabel='rest_type', ylabel='count'>

# %% [markdown]
# restaurant type

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
x = df.groupby('location')['rate'].mean().sort_values(ascending = False).head(30)
x.plot(kind  = 'bar')

# sns.countplot(data=df,x ='location')
# Out:
# <Axes: xlabel='location'>

# %% [markdown]
# plotting the most famous restaurant chains in Bengaluru according to the rate

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...
